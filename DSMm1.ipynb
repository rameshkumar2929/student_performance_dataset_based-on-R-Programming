# %%
data<-read.csv("Students Performance.csv")
head(data)
# Out:
#   Math_Score Reading_Score Writing_Score Placement_Score Club_Join_Date
# 1 65         86            67            78              2021
# 2 64         85            71            80              2019
# 3 76         77            77            84              2021
# 4 80         76            75            75              2021
# 5 63         91            62            90              2019
# 6 73         95            62            79              2020

# %%
View(data)
# Out:
#     Math_Score Reading_Score Writing_Score Placement_Score Club_Join_Date
# 1   65         86            67             78             2021
# 2   64         85            71             80             2019
# 3   76         77            77             84             2021
# 4   80         76            75             75             2021
# 5   63         91            62             90             2019
# 6   73         95            62             79             2020
# 7   72         82            76             79             2020
# 8   77         82            62             87             2021
# 9   74         90            60            100             2019
# 10  68         85            72             89             2019
# 11  64         78            80             84             2019
# 12  75         83            76             83             2019
# 13  62         89            61             76             2019
# 14  69         80            73             87             2021
# ...

# %%
str(data)
# Out:
# 'data.frame':	399 obs. of  5 variables:
#  $ Math_Score     : int  65 64 76 80 63 73 72 77 74 68 ...
#  $ Reading_Score  : int  86 85 77 76 91 95 82 82 90 85 ...
#  $ Writing_Score  : int  67 71 77 75 62 62 76 62 60 72 ...
#  $ Placement_Score: int  78 80 84 75 90 79 79 87 100 89 ...
#  $ Club_Join_Date : int  2021 2019 2021 2021 2019 2020 2020 2021 2019 2019 ...

# %%
summary(data)
# Out:
#    Math_Score     Reading_Score    Writing_Score    Placement_Score
#  Min.   : 60.00   Min.   : 60.00   Min.   : 60.00   Min.   : 60.00
#  1st Qu.: 69.00   1st Qu.: 70.00   1st Qu.: 68.00   1st Qu.: 71.00
#  Median : 79.00   Median : 80.00   Median : 78.00   Median : 80.00
#  Mean   : 79.18   Mean   : 79.68   Mean   : 79.17   Mean   : 80.35
#  3rd Qu.: 90.00   3rd Qu.: 89.00   3rd Qu.: 90.00   3rd Qu.: 89.00
#  Max.   :100.00   Max.   :100.00   Max.   :100.00   Max.   :100.00
#  Club_Join_Date
#  Min.   :2018
#  1st Qu.:2018
#  Median :2019
#  Mean   :2019
#  3rd Qu.:2020
#  Max.   :2021

# %%
dim(data)
# Out:
# [1] 399   5

# %%
names(data)
# Out:
# [1] "Math_Score"      "Reading_Score"   "Writing_Score"   "Placement_Score"
# [5] "Club_Join_Date"

# %%
tail(data)
# Out:
#     Math_Score Reading_Score Writing_Score Placement_Score Club_Join_Date
# 394  94        93            78            69              2019
# 395  85        95            74            60              2020
# 396  67        87            96            93              2021
# 397  92        81            93            64              2021
# 398 100        64            97            88              2021
# 399  63        78            85            93              2020

# %%
sum(is.na(data))
# Out:
# [1] 0

# %%
colSums(is.na(data))
# Out:
#      Math_Score   Reading_Score   Writing_Score Placement_Score  Club_Join_Date
#               0               0               0               0               0

# %%
sum(duplicated(data))
# Out:
# [1] 0

# %%
sapply(data,class)
# Out:
#      Math_Score   Reading_Score   Writing_Score Placement_Score  Club_Join_Date
#       "integer"       "integer"       "integer"       "integer"       "integer"

# %%
sapply(data,function(x)length(unique(x)))
# Out:
#      Math_Score   Reading_Score   Writing_Score Placement_Score  Club_Join_Date
#              41              41              41              41               4

# %%
table(data$Writing_Score)
# Out:
#  60  61  62  63  64  65  66  67  68  69  70  71  72  73  74  75  76  77  78  79
#  14  13  11   9   5  16   9  11  13   8   9   9  11  13  11   9  13   8  11   5
#  80  81  82  83  84  85  86  87  88  89  90  91  92  93  94  95  96  97  98  99
#  12   6   6   9   7   8   8   4  16  11  10  14   6  11  12   7   8   9  15   6
# 100
#   6

# %%
hist(data$Math_Score,
     main="data Distribution",
     xlab="Marks_Score",
     col="blue")
# Out:
# Plot with title “data Distribution”
